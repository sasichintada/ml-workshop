# %% [markdown]
# <a href="https://colab.research.google.com/github/sasichintada/ml-workshop/blob/main/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Basic Line Plot

# %% [markdown]
# Plot a simple line graph of 𝑦 = 𝑥
# 2
# for 𝑥 values ranging from -10 to 10.
# . Label the x-axis as "X Values" and the y-axis as "Squared Values."
# . Add a title to the graph.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ####plotting

# %%
#x varies -10 to 10
x=np.linspace(-10,10,100)
#curve
y = x**2
#plotting the curve
plt.plot(x, y)

# %% [markdown]
# ####label

# %%
plt.xlabel('X Values')
plt.ylabel('Squared Values')
# Out:
# Text(0, 0.5, 'Squared Values')

# %% [markdown]
# ####title

# %%
plt.title('graph')
#display
plt.show()

# %% [markdown]
# ####Bar Plot

# %% [markdown]
# Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi',
# 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88].Add labels to the x-axis and y-axis and give the chart a title.

# %%
#marks scored by five students
students=np.array(['sai','vamsi','divij','sritan','sita'])
marks=np.array([85,90,78,92,88])
#creates a bar
plt.bar(students,marks)
#labels and title
plt.xlabel('students')
plt.ylabel('marks')
plt.title('marks scored')
#display the plot
plt.show()

# %% [markdown]
# ####Scatter Plot

# %% [markdown]
# Generate two lists of 20 random integers each (for x and y coordinates).Create a scatter plot with these values, and customize it by adding color,
# size, and labels to the points.

# %%
#random numbers for x and y
x=np.random.randint(1,100,20)
y=np.random.randint(1,100,20)
#scatter plot for x and y values
plt.scatter(x,y,color='darkgreen',marker='*')
#labels for x and y axis
plt.xlabel('x-axis')
plt.ylabel('y-axis')
#display the plot
plt.show()

# %% [markdown]
# ####Histogram

# %% [markdown]
# Simulate 100 random values from a normal distribution using
# np.random.randn() and plot a histogram.
# Customize the number of bins and add a grid to the plot

# %%
#stimulating 100 random numbers
data=np.random.randn(100)
#creating a histogram with bins
plt.hist(data, bins=10, color='skyblue',edgecolor='black')
#labels and title for the plot
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Histogram')
#grid is used to simplify the plot
plt.grid(True)
#display the plot
plt.show()

# %% [markdown]
# ####Pie Chart

# %% [markdown]
# Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E']
# with values [20, 30, 25, 15, 10].
# Display the percentage values on the chart and use a color palette for
# differentiation.

# %%
#data set with categories and values
categories=['A','B','C','D','E']
values=[20,30,25,15,10]
#colors for each part of pie
colors=['lightblue','pink','orange','red','maroon']
#plotting a pie chart
plt.pie(values, labels=categories, colors=colors)
#title for the pie chart
plt.title('Distribution of 5 categories')
#display
plt.show()

# %% [markdown]
# ####Box Plot (Seaborn)

# %% [markdown]
# Create a box plot to visualize the distribution of the marks scored by
# students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].
#  Highlight the median and any outliers.

# %%
import seaborn as sns

# %%
#distribution of marks
marks=[78,85,92,88,76,95,89,84,91,73]
#plotting a boxplot
sns.boxplot(marks)
#display
plt.show()

# %% [markdown]
# ####Heatmap (Seaborn)

# %% [markdown]
# Create a 5x5 matrix with random integers between 1 and 10 using
# np.random.randint() and visualize it as a heatmap using Seaborn.
# Add a color bar and annotate the heatmap with the values.

# %%
#creating a matrix with random integers from to 10 with shape(5,5)
matrix=np.random.randint(1,10,(5,5))
#plotting a heatmap
sns.heatmap(matrix,annot=True,cmap='YlGnBu')
#display
plt.show()

# %% [markdown]
# Comparison of Matplotlib and Seaborn
# Generate a pair of plots (bar charts or line plots) using the same data in
# both Matplotlib and Seaborn.
#  Highlight the differences in the code, syntax, and aesthetics of the two
# libraries

# %%
#dataset with quantity and price
data = {
    'Quantity': [10, 20, 30, 40, 50],
    'Price': [5, 6, 7, 8, 9]
}
df = pd.DataFrame(data)

# %% [markdown]
# ####Matplotlib

# %%
import matplotlib.pyplot as plt
# Line Plot
plt.plot(df['Quantity'], df['Price'],marker='o',color='green')
plt.title('matplotlib')
plt.xlabel('Quantity')
plt.ylabel('Price')
#display
plt.show()

# %% [markdown]
# #### Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Line Plot
sns.lineplot(x='Quantity', y='Price', data=df, marker='o', color='green')
plt.title('Seaborn')
plt.xlabel('Quantity')
plt.ylabel('Price')
#display
plt.show()

# %% [markdown]
#  **Differences in the code, syntax, and aesthetics of the two libraries**

# %% [markdown]
# **Code**
#
# *   **Matplotlib :** It contains more lines of code and we have to set it manually
# *   **Seaborn :**  Shorter code and most of the things have automatic functionality
#
# **Syntax**
#
#
# * **Matplotlib :** You need to use separate commands for labels and colors
# * **Seaborn :**  Easier syntax with functions
#
# **Aesthetics:**
#
#
# *  **Matplotlib:** The plots are simple and plain.we need to add styling for it
# *  **Seaborn:** By default the plots are with good colors,grids and formatting

# %% [markdown]
# ####Pair Plot(seaborn)

# %% [markdown]
# Manually create a small dataset with columns such as 'Age', 'Height',
# 'Weight' for 10 individuals and visualize the relationships using a pair plot

# %%
import pandas as pd

# %%
# creating a dataset
data={
    'Age':[20,30,40,11,32,12,44,55,32,10],
    'Height':[171,165,168,160,176,163,172,164,180,178],
    'Weight':[45,55,43,41,30,56,53,52,35,33]
}
# creating the dataframe for the above data
df=pd.DataFrame(data)
#creating a pairplot for visualisingthe relationships between the dataset columns
sns.pairplot(df)
#displaying the results
plt.show()

# %% [markdown]
# ###Save and Style Plots

# %% [markdown]
#  Plot any graph of your choice and save it in both .png and .pdf formats.
#  Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain
# how the style impacts the visualization

# %%
x = np.linspace(-10, 10, 400) #values of x
y = x**2   #value of y
plt.style.use('ggplot') #using ggplot style
plt.plot(x, y,label='x^2', linewidth=2)
#labels for x,y axis
plt.xlabel('X Values')
plt.ylabel('Y Values')
#title for the plot
plt.title('y = x^2')
plt.legend()
# plots as png and pdf
plt.savefig('x_squared_plot.png')
plt.savefig('x_squared_plot.pdf')
#display the plot
plt.show()
